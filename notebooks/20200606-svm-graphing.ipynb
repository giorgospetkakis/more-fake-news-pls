# %%
import pandas as pd
import data
import preprocessing
import numpy as np
import scipy.stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Authors = data.get_processed_data()
Data, truth, d0, y0 = data.get_prepared_data(split=1)

# %%
Data = d0
y = y0

# %%
y.mean()
# Out:
# 0.5

# %%
df = data.get_csv()

# %%
df = df.set_index("author_id")

# %%
df['truth'].loc

# %%
mis = df.loc[df['truth'] == 1]
true = df.loc[df['truth'] == 0]

# %%
mis['readability'].mean()
# Out:
# 8.12146666666666

# %%
true['readability'].mean()
# Out:
# 7.834199999999992

# %%
plt.hist(mis['readability'])
plt.hist(true[''])
# Out:
# (array([ 1.,  3.,  5., 18., 25., 37., 34., 16.,  7.,  4.]),
#  array([ 3.52,  4.29,  5.06,  5.83,  6.6 ,  7.37,  8.14,  8.91,  9.68,
#         10.45, 11.22]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(mis['TTR'])
plt.hist(true['TTR'],alpha=0.5)
# Out:
# (array([  4.,   0.,   0.,   2.,   3.,   3.,   4.,   5.,   9., 120.]),
#  array([0.29 , 0.361, 0.432, 0.503, 0.574, 0.645, 0.716, 0.787, 0.858,
#         0.929, 1.   ]),
#  <a list of 10 Patch objects>)

# %%
df.keys()
# Out:
# Index(['readability', 'TTR', 'max_similar', 'min_similar', 'mean_similar',
#        'number_identical', 'mcts_ner', 'mcts_adj', 'url_max', 'url_mean',
#        'hashtag_max', 'hashtag_mean', 'user_max', 'user_mean', 'emoji_mean',
#        'emoji_max', 'exclamation_mean', 'exclamation_max', 'period_mean',
#        'period_max', 'question_mean', 'question_max', 'comma_mean',
#        'comma_max', 'allcaps_ratio', 'allcaps_inclusion_ratio',
#        'titlecase_ratio', 'mean_words', 'retweet_percentage', 'ADJ', 'ADP',
#        'ADV', 'AUX', 'CONJ', 'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART',
#        'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'SYM', 'VERB', 'X', 'anger', 'fear',
#        'anticipation', 'trust', 'surprise', 'sadness', 'joy', 'disgust',
#        'positive', 'negative', 'truth'],
#       dtype='object')

# %%
plt.hist(mis['mean_words'])
plt.hist(true['mean_words'], alpha=0.5)
# Out:
# (array([ 7.,  3., 10., 22., 37., 30., 14., 12.,  6.,  9.]),
#  array([ 3.22 ,  4.746,  6.272,  7.798,  9.324, 10.85 , 12.376, 13.902,
#         15.428, 16.954, 18.48 ]),
#  <a list of 10 Patch objects>)

# %%
mis['PROPN'].mean()
# Out:
# 3.9781999999999593

# %%
mis.loc[mis['number_identical'] == 0]
# Out:
#                                   readability   TTR  max_similar  min_similar  \
# author_id
# q91ww3hmw5lof951ts61p3mu52oxrl3o         8.66  1.00     0.996152     0.554930
# 6rafm58i0f3qq9q646staz263l7zx23z         7.69  1.00     0.955914     0.247685
# t72vej72nk7lc5tbfo59icweo0c94no7         7.52  1.00     0.934916     0.380456
# h56srndge9i25ksdtajjfgsm10e59kgb         6.82  1.00     0.967161     0.216424
# veiwupaigla1qbijyxu3oujyjumg7wio         9.03  1.00     0.957299     0.568184
# 8y3vw5wsbj8lefvmwar3v297dbkd4hiq  0.703067  0.784265  1.348428  1.989328
# 99u7e2kcxz3d8fzaqblow0fgl9u06eeg  0.933237  0.141939  1.513427  0.547077
# 36w54uf2991wiao1halknad31ezvotiz  0.410889  0.331345  1.034593  1.106698
# ryzyq2dmk3gg9oinvwi2ujutu0jzs4iw  1.133230  0.082655  1.731948  0.397303
# ...                                    ...       ...       ...       ...
# iqx2tqavqtpmh1kdn5wnt2wvlvt4me97  0.679103  0.143113  0.993220  0.437569
# ogecvmquvmgwazab0osmth2eaieiejsv  1.256070  0.262498  1.901268  0.791314
# l34d9zzi2gk1784oqmeycg8hffjr5t18  0.314671  0.242553  1.094922  1.204947
# n3l9sc6sinb2up1qxytkppkaq2cu4hd0  0.395150  0.090904  1.107565  0.265684
# 4whbe0y9fno5nfmxnqzwwydx5oqqy3py  0.580320  0.262159  1.403263  0.694719
#
#                                   truth
# author_id
# jztc6t415ocxtnioyvgzddv49j3pcus4      0
# 8y3vw5wsbj8lefvmwar3v297dbkd4hiq      0
# 99u7e2kcxz3d8fzaqblow0fgl9u06eeg      0
# 36w54uf2991wiao1halknad31ezvotiz      0
# ryzyq2dmk3gg9oinvwi2ujutu0jzs4iw      0
# ...                                 ...
# iqx2tqavqtpmh1kdn5wnt2wvlvt4me97      0
# ogecvmquvmgwazab0osmth2eaieiejsv      0
# l34d9zzi2gk1784oqmeycg8hffjr5t18      0
# n3l9sc6sinb2up1qxytkppkaq2cu4hd0      0
# 4whbe0y9fno5nfmxnqzwwydx5oqqy3py      0
#
# [77 rows x 58 columns]

# %%
emotion = "anger"
plt.figure(figsize=(10,8))
plt.hist(true[emotion], alpha=0.7, label="Real news")
plt.hist(mis[emotion], alpha=0.7, label="Fake news")
plt.legend()
plt.title(emotion)
plt.savefig("reports/figures/{}.png".format(emotion))

# %%
true.keys()
# Out:
# Index(['readability', 'TTR', 'max_similar', 'min_similar', 'mean_similar',
#        'number_identical', 'mcts_ner', 'mcts_adj', 'url_max', 'url_mean',
#        'hashtag_max', 'hashtag_mean', 'user_max', 'user_mean', 'emoji_mean',
#        'emoji_max', 'exclamation_mean', 'exclamation_max', 'period_mean',
#        'period_max', 'question_mean', 'question_max', 'comma_mean',
#        'comma_max', 'allcaps_ratio', 'allcaps_inclusion_ratio',
#        'titlecase_ratio', 'mean_words', 'retweet_percentage', 'ADJ', 'ADP',
#        'ADV', 'AUX', 'CONJ', 'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART',
#        'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'SYM', 'VERB', 'X', 'anger', 'fear',
#        'anticipation', 'trust', 'surprise', 'sadness', 'joy', 'disgust',
#        'positive', 'negative', 'truth'],
#       dtype='object')

# %%
plt.hist(true['TTR'], alpha=0.7, label="Real news")
plt.hist(mis['TTR'], alpha=0.7, label="Fake news")
plt.legend()
plt.show()

# %%
plt.hist(true['sadness'], alpha=0.7, label="Real news")
plt.hist(mis['sadness'], alpha=0.7, label="Fake news")
plt.legend()
plt.show()
